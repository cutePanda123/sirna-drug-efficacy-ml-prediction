# %%
################################################
# 安装依赖
################################################

# !pip install pandas
# !pip install torch
# !pip install lightgbm
# !pip install numpy
# !pip install scikit-learn
# !pip install tqdm
# !pip install rich
# !pip install multimolecule
# !pip install chardet
# !pip install datetime
